# %% [markdown]
# # THE SPARK FOUNDATION - GRIP
# **Data Science And Business Analytics**
# **Task1:- Prediction using supervised ML**
# **BY Sonali Patil**                                                                                                             **Problem Statement:- What will be a prediction
